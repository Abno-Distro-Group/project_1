# %%
#dependencies and importing csv
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

path = "IMDB-Movie-Data.csv"

movie_data = pd.read_csv(path)
movie_data = movie_data.dropna()
movie_data.count()
# Out:
# Rank                  838
# Title                 838
# Genre                 838
# Description           838
# Director              838
# Actors                838
# Year                  838
# Runtime (Minutes)     838
# Rating                838
# Votes                 838
# Revenue (Millions)    838
# Metascore             838
# dtype: int64

# %%
#revenue earnings based off genre

for index, row in movie_data.iterrows():
   movie_data['Genre'][index] = movie_data['Genre'][index].split(',')[0]

movie_data.head()

genre_grouped = movie_data.groupby("Genre")

revenue = genre_grouped["Revenue (Millions)"].mean()


revenue.plot(kind='bar', color = 'g')
plt.show()
# Out:
# C:\Users\frcon\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#line graph - revenue earnings compared to runtime

#line average earnings for run times
runtime_grouped = movie_data.groupby("Runtime (Minutes)")
avg_rev = runtime_grouped["Revenue (Millions)"].mean()




line_plot = avg_rev.plot(kind="line", color = 'g')
line_plot.set_title("Average Revenue by Film Runtime")
line_plot.set_ylabel("Average Revenue (Millions)")
line_plot.set_xlabel("Runtimes")

plt.xlim(80,190)
plt.ylim(0,max(avg_rev))

plt.show()
plt.tight_layout()

# %%
#Scatter plot - runtimes by revenue
runtime = movie_data.loc[:,"Runtime (Minutes)"]
revenue = movie_data.loc[:,"Revenue (Millions)"]


plt.scatter(runtime,revenue, marker= 'o', alpha = .5, color = 'g')


# x_values = runtime
# y_values = revenue
# (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(20,40),fontsize=15,color="red")
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Revenue (Millions)')
plt.title("Runtime verus Revenue")
# plt.ylim(0,max(y_values))
# plt.xlim(0,max(x_values))
# plt.grid()


plt.show()

# %%
movie_data.head()
# Out:
#    Rank                    Title      Genre  \
# 0     1  Guardians of the Galaxy     Action
# 1     2               Prometheus  Adventure
# 2     3                    Split     Horror
# 3     4                     Sing  Animation
# 4     5            Suicide Squad     Action
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# ...

# %%
genres= movie_data["Genre"].value_counts()
x_axis= np.arange(len(movie_data))

# %%
graph1=genres[:40].plot(kind="bar", color="r")
graph1

# %%
graph2=revenue[:20].plot(kind="bar", color="r")
graph2

# %%
sorted=movie_data.sort_values(by='Revenue (Millions)', ascending=False)
graph4= sorted[:30].plot.barh(x="Title", y="Revenue (Millions)", rot=0, title="Top Grossing Movies", alpha=0.5, align="center", figsize=(10,10))
graph4

# %%
#Scatter plot - runtimes by revenue
genre = movie_data["Genre"]
revenue = movie_data["Revenue (Millions)"]


plt.scatter(genre,revenue, marker= 'o', alpha = .3, color = 'b')



plt.xlabel('Runtime (Minutes)')
plt.ylabel('Revenue (Millions)')
plt.title("Runtime verus Revenue")
# Out:
# Text(0.5, 1.0, 'Runtime verus Revenue')

# %%
sorted=movie_data.sort_values(by='Revenue (Millions)', ascending=False)
graph4= sorted[:30].plot.barh(x="Genre", y="Revenue (Millions)", rot=0, title="Top Grossing Movies", alpha=0.5, align="center", figsize=(20,10))
graph4

# %%
movie_data["Year"].value_counts()
# Out:
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: Year, dtype: int64

# %%
#movie_data1= movie_data["Year"].drop({"2013", "2014"}, axis=0)

# %%
#movie_data["Year"].dt.strftime("%y%m%d").astype(int)
movie_data["Genre"].value_counts()
# Out:
# Action       268
# Comedy       151
# Drama        148
# Adventure     68
# Biography     55
# Crime         53
# Animation     45
# Horror        34
# Mystery       11
# Sci-Fi         2
# Fantasy        2
# Thriller       1
# Name: Genre, dtype: int64

# %%
#movie_data.set_index("Genre")
#movie_data.drop("Comedy", axis=0)

# %%
#directorct=movie_data["Director"].value_counts()

# %%
#graph5= sorted.plot.barh(x=directorct, rot=0, title="Top Grossing Movies", alpha=0.5, align="center", figsize=(20,10))
#graph5

# %%
actionstats= movie_data.loc[movie_data["Year"] == 2008]

# %%
actionstats.head()
# Out:
#      Rank            Title   Genre  \
# 54     55  The Dark Knight  Action
# 128   129       Mamma Mia!  Comedy
# 165   166         Twilight   Drama
# 177   178   Tropic Thunder  Action
# 203   204         Iron Man  Action
#
#                                            Description             Director  \
# 54   When the menace known as the Joker wreaks havo...    Christopher Nolan
# 128  The story of a bride-to-be trying to find her ...       Phyllida Lloyd
# 165  A teenage girl risks everything when she falls...  Catherine Hardwicke
# 177  Through a series of freak occurrences, a group...          Ben Stiller
# 203  After being held captive in an Afghan cave, bi...          Jon Favreau
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 128  Meryl Streep, Pierce Brosnan, Amanda Seyfried,...  2008
# 165  Kristen Stewart, Robert Pattinson, Billy Burke...  2008
# ...

# %%
#graph5= sorted[:30].plot.barh(x=actionstats["Title"], y=actionstats["Revenue (Millions)"], rot=0, title="Top Grossing Movies", alpha=0.5, align="center", figsize=(20,10))
#graph5
graph5= actionstats[:30].plot.barh(x="Genre", y= "Revenue (Millions)", rot=0, title="Top Grossing Movies", alpha=0.5, align="center", figsize=(20,10))
graph5

# %%
actionstats["Genre"].value_counts()
# Out:
# Action       22
# Drama         9
# Comedy        8
# Biography     3
# Horror        2
# Sci-Fi        1
# Animation     1
# Crime         1
# Adventure     1
# Name: Genre, dtype: int64

# %%
actionstats2007= movie_data.loc[movie_data["Year"] == 2007]

# %%
actionstats2007["Genre"].value_counts()
# Out:
# Action       9
# Drama        8
# Crime        7
# Adventure    6
# Comedy       5
# Animation    3
# Biography    3
# Horror       2
# Fantasy      1
# Name: Genre, dtype: int64

# %%
sorted["Genre"][:100]
# Out:
# 50        Action
# 87        Action
# 85        Action
# 76        Action
# 54        Action
#          ...
# 407    Animation
# 528       Action
# 169       Action
# 924       Action
# 715    Animation
# Name: Genre, Length: 100, dtype: object

# %%
sort100=sorted["Revenue (Millions)"][:100].head()

# %%
sort100=sorted[:246]

# %%
milli100=sort100["Genre"].value_counts()

# %%
mil100 = milli100.rename_axis('Genre').reset_index(name='counts')
print (mil100)
sort100
# Out:
#        Genre  counts
# 0     Action     119
# 1  Animation      33
# 2     Comedy      28
# 3  Adventure      27
# 4      Drama      15
# 5  Biography      12
# 6      Crime       6
# 7    Mystery       3
# 8     Horror       3
#      Rank                                       Title      Genre  \
# 50     51  Star Wars: Episode VII - The Force Awakens     Action
# 87     88                                      Avatar     Action
# 85     86                              Jurassic World     Action
# 76     77                                The Avengers     Action
# 54     55                             The Dark Knight     Action
# ..    ...                                         ...        ...
# 19     20                                     Arrival      Drama
# 360   361                               Step Brothers     Comedy
# 200   201                            Edge of Tomorrow     Action
# 837   838               You Don't Mess with the Zohan     Action
# ...

# %%
graph6= mil100.plot.bar(x="Genre", y= "counts", rot=0, title="Genres of Movies With Revenues over 100 Million USD", alpha=0.5, align="center", figsize=(20,10))
graph6

# %%
#Scatter plot - runtimes by revenue
genre = movie_data["Genre"]
revenue = movie_data["Revenue (Millions)"]


movie_data.boxplot(column="Revenue (Millions)", by="Genre", fontsize=9, rot=0, grid=True, figsize=None, layout=None, return_type=None)



plt.gcf().set_size_inches((10, 10))
plt.show()
